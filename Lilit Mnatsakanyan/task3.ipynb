# %% [markdown]
# #### The task is to perform some data cleaning and extraction on the Coachella Tweets dataset, which contains tweets related to the Coachella music festivalThe task is to perform some data cleaning and extraction on the Coachella Tweets dataset, which contains tweets related to the Coachella music festival

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\lilit\PycharmProjects\nlp-course-2025.1\Lilit Mnatsakanyan\data\Coachella-2015-2-DFE.csv",
                 encoding='cp1252',
                 encoding_errors='replace')

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
import nltk
import re
import string

# %%
# df["preprocessed_text"]=

# %%
df["hashtags"] = df["text"].str.findall(r"#\w+")

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
df["preprocessed_text"] = df["text"].str.replace(r"#\w+", "", regex=True).str.strip()

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
df["emails"] = df["text"].str.findall(r"\w+@\w+.\w+")
df["preprocessed_text"] = df["preprocessed_text"].str.replace(r"\w+@\w+.\w+", "", regex=True).str.strip()

# %%
df["usernames"] = df["preprocessed_text"].str.findall(r"@\w+")

# %%
df["preprocessed_text"] = df["preprocessed_text"].str.replace(r"@\w+", "", regex=True).str.strip()

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
df["links"] = df["preprocessed_text"].str.findall(r"https?://\w+.\w+.\w+\S+")

# %%
df["preprocessed_text"] = df["preprocessed_text"].str.replace(r"https?://\w+.\w+.\w+\S+", "", regex=True).str.strip()

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
df["preprocessed_text"] = df["preprocessed_text"].str.lower()

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
df["numbers"] = df["preprocessed_text"].str.findall(r"\d+")

df["preprocessed_text"] = df["preprocessed_text"].str.replace(r"\d+", "", regex=True)

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
df["special_characters"] = df["preprocessed_text"].str.findall(r"[^\w\s]")

df["preprocessed_text"] = df["preprocessed_text"].str.replace(r"[^\w\s]", "", regex=True)

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
df["non_ascii"] = df["preprocessed_text"].str.findall(r"[^A-Za-z\s]")

df["preprocessed_text"] = df["preprocessed_text"].str.replace(r"[^A-Za-z\s]", "", regex=True)

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
def remove_non_ascii(text):
    return text.encode("ascii", errors="ignore").decode()
df["preprocessed_text"] = df["preprocessed_text"].apply(remove_non_ascii)

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...

# %%
df["preprocessed_text"] = df["preprocessed_text"].str.replace(r"\s+", " ", regex=True)

# %%
df
# Out:
#      coachella_sentiment coachella_yn            name  retweet_count  \
# 0               positive          yes        kokombil              0
# 1               positive          yes   MisssTaraaa10              2
# 2               positive          yes   NMcCracken805              0
# 3               positive          yes          wxpnfm              1
# 4               positive          yes        Caesears              0
# ...                  ...          ...             ...            ...
# 3841           cant tell          yes   MissXOverdose              0
# 3842           cant tell          yes      NedRaggett              1
# 3843           cant tell          yes  nicolejackieee              0
# 3844           cant tell          yes    NiqueWobbitz              2
# 3845           cant tell          yes    LindsayRuben              1
#
#                                                    text tweet_coord  \
# 0     #Coachella2015 tickets selling out in less tha...  [0.0, 0.0]
# ...
